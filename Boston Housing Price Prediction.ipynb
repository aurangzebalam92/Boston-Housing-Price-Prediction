# %% [markdown]
# # Project Name - Boston Housing Price Prediction

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
os.chdir("E:/Data Science/Data Science/Edureka/Case Studies/1. BostonHousing")

# %%
os.getcwd()
# Out:
# 'E:\\Data Science\\Data Science\\Edureka\\Case Studies\\1. BostonHousing'

# %%
#Load the data
Dataset = pd.read_csv("boston.csv")

# %%
#Top 5 head of the Dataset
Dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#Check the info of the Dataset
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NX         506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
#Statistical information of the Dataset
Dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS          NX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
#Columns name of Dataset
Dataset.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
#Numerical Columns
numerical_columns = Dataset.select_dtypes(include=[np.number]).columns.tolist()
numerical_columns
# Out:
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT',
#  'MEDV']

# %%
#Categorical Columns
categorical_columns = Dataset.select_dtypes(exclude=[np.number]).columns.tolist()
categorical_columns
# Out:
# []

# %% [markdown]
# # Data Exploration

# %%
#Missing value
missing_value = pd.DataFrame(Dataset.isnull().sum())
missing_value
# Out:
#          0
# CRIM     0
# ZN       0
# INDUS    0
# CHAS     0
# NX       0
# RM       0
# AGE      0
# DIS      0
# RAD      0
# TAX      0
# PTRATIO  0
# B        0
# LSTAT    0
# MEDV     0

# %%
#Plot the histogram to see the missing values 
import seaborn as sns
sns.set()
sns.heatmap(Dataset.isnull(),cbar=True)

# %%
#Plot pairwise relationships in a Dataset and fit linear regression models to the scatter plot
sns.pairplot(Dataset)

# %%
#Correlation coefficient
plt.figure(figsize=(10,10))
sns.heatmap(Dataset.corr(),square=True,annot=True)

# %%
#Columns list
Dataset.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
#Splitting Dataset into Independent and Dependent variables
X = Dataset[['CRIM', 'ZN', 'INDUS', 'NX', 'RM', 'AGE', 'RAD', 'TAX','PTRATIO', 'B', 'LSTAT']]

y = Dataset['MEDV']

# %%
#Creating training and test Dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
#shape of X_train
X_train.shape
# Out:
# (354, 11)

# %%
#Shape of X_test
X_test.shape
# Out:
# (152, 11)

# %%
#Import Linear Regression Model and instantiate a Linear Regression Object
from sklearn.linear_model import LinearRegression
Linear_Regration = LinearRegression()  # Linear_Regration is the object of class Linear Regression

# %%
# Learning from Data using Linear Regression
Linear_Regration.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#Coefficient of Linear Regression
Linear_Regration.coef_
# Out:
# array([-7.08774699e-02,  6.02826888e-03,  1.40793573e-01, -1.07932935e+01,
#         3.68623860e+00,  4.51057442e-02,  3.02471744e-01, -1.25256105e-02,
#        -1.12571250e+00,  7.00719662e-03, -6.16954539e-01])

# %%
#Intercept values 
Linear_Regration.intercept_
# Out:
# 28.947976080975142

# %%
#Apply my learning data and the prediction
y_prediction = Linear_Regration.predict(X_test)

# %%
plt.scatter(y_test,y_prediction)

# %%
#Plot the Resudual Error
sns.distplot(y_test - y_prediction)

# %%
#Publish the accuracy metrics
from sklearn import metrics
metrics.mean_absolute_error(y_test, y_prediction) #Mean Absolute Error
# Out:
# 3.983117369362514

# %%
# RMSE = root mean squared error = on an average your prediction is of by 5 units
np.sqrt(metrics.mean_absolute_error(y_test, y_prediction))
# Out:
# 1.9957748794296701

# %%
#r2 = % of variations explained by model = overall what amount of base error is model able to reduce
metrics.r2_score(y_test, y_prediction)
# Out:
# 0.6858670482161662
